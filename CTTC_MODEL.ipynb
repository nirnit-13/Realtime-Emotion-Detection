# %% [markdown]
# #MODEL TRAINING

# %%
import pickle
import numpy as np
import tensorflow as tf
import keras

# %%
#Loading the data from pickle file:
with open('images.p','rb') as f:
    x = pickle.load(f)
with open('labels.p','rb') as f:
    y = pickle.load(f)

# %%
print("Images: ",x.shape)
print("Labels: ",y.shape)
# Out:
# Images:  (16082, 48, 48)
# Labels:  (16082,)

# %%
#Label encoding output
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
y
# Out:
# array([0, 0, 0, ..., 4, 4, 4])

# %%
# Standardizing the images for CNN Model:
x = x/255
x = x.reshape(-1,48,48,1)

# %%
# using one-hot encoding to output column
from keras.utils import to_categorical
y = to_categorical(y)

# %%
# Splitting, training and testing datas
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.1)

# %%
print("Xtrain: ", xtrain.shape)
print("Xtest: ", xtest.shape)
print("Ytrain: ", ytrain.shape)
print("Ytest: ", ytest.shape)
# Out:
# Xtrain:  (14473, 48, 48, 1)
# Xtest:  (1609, 48, 48, 1)
# Ytrain:  (14473, 5)
# Ytest:  (1609, 5)

# %%
# CNN Model Training
from keras.models import Sequential
from keras.optimizers import Adam
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout

# %%
model = Sequential()

# 1st Convolutional Layer:
model.add(Conv2D(45, (3,3), activation='relu', input_shape=(48,48,1)))
model.add(MaxPooling2D(pool_size=(2,2)))

# 2nd Convolutional Layer:
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# 3rd Convolutional Layer:
model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# Adding flatten layer: converts 2D to 1D
model.add(Flatten())

# Hidden Layer
model.add(Dense(256, activation='relu'))

# Output Layer
model.add(Dense(5, activation='softmax'))
model.compile(Adam(learning_rate=0.001), loss= 'categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 46, 46, 45)     │           450 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 23, 23, 45)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 21, 21, 64)     │        25,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 10, 10, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 626,119 (2.39 MB)
#  Trainable params: 626,119 (2.39 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(xtrain, ytrain, epochs=20, validation_data=(xtest, ytest))
# Out:
# Epoch 1/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 65s 139ms/step - accuracy: 0.2955 - loss: 1.5343 - val_accuracy: 0.4910 - val_loss: 1.2713
# Epoch 2/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 80s 135ms/step - accuracy: 0.5104 - loss: 1.1988 - val_accuracy: 0.5712 - val_loss: 1.0940
# Epoch 3/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 81s 133ms/step - accuracy: 0.5894 - loss: 1.0380 - val_accuracy: 0.5855 - val_loss: 1.0413
# Epoch 4/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 60s 133ms/step - accuracy: 0.6276 - loss: 0.9492 - val_accuracy: 0.6041 - val_loss: 1.0269
# Epoch 5/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 83s 135ms/step - accuracy: 0.6702 - loss: 0.8558 - val_accuracy: 0.6140 - val_loss: 0.9967
# Epoch 6/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 61s 135ms/step - accuracy: 0.7116 - loss: 0.7578 - val_accuracy: 0.6109 - val_loss: 1.0013
# Epoch 7/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 60s 133ms/step - accuracy: 0.7470 - loss: 0.6766 - val_accuracy: 0.6221 - val_loss: 1.0187
# Epoch 8/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 61s 135ms/step - accuracy: 0.7817 - loss: 0.5893 - val_accuracy: 0.6116 - val_loss: 1.0794
# Epoch 9/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 62s 137ms/step - accuracy: 0.8095 - loss: 0.5134 - val_accuracy: 0.6271 - val_loss: 1.1883
# Epoch 10/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 61s 135ms/step - accuracy: 0.8536 - loss: 0.4024 - val_accuracy: 0.6172 - val_loss: 1.2258
# Epoch 11/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 81s 133ms/step - accuracy: 0.8920 - loss: 0.3159 - val_accuracy: 0.6122 - val_loss: 1.3291
# Epoch 12/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 63s 138ms/step - accuracy: 0.9156 - loss: 0.2422 - val_accuracy: 0.6022 - val_loss: 1.5368
# Epoch 13/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 62s 137ms/step - accuracy: 0.9357 - loss: 0.1949 - val_accuracy: 0.5979 - val_loss: 1.7381
# Epoch 14/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 62s 136ms/step - accuracy: 0.9596 - loss: 0.1256 - val_accuracy: 0.6265 - val_loss: 1.8758
# Epoch 15/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 80s 133ms/step - accuracy: 0.9655 - loss: 0.1065 - val_accuracy: 0.6097 - val_loss: 2.0449
# Epoch 16/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 85s 139ms/step - accuracy: 0.9659 - loss: 0.1077 - val_accuracy: 0.6215 - val_loss: 2.2283
# Epoch 17/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 81s 136ms/step - accuracy: 0.9791 - loss: 0.0665 - val_accuracy: 0.5898 - val_loss: 2.4029
# Epoch 18/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 61s 135ms/step - accuracy: 0.9751 - loss: 0.0755 - val_accuracy: 0.6277 - val_loss: 2.4831
# Epoch 19/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 83s 139ms/step - accuracy: 0.9835 - loss: 0.0548 - val_accuracy: 0.6066 - val_loss: 2.5477
# Epoch 20/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 80s 135ms/step - accuracy: 0.9792 - loss: 0.0634 - val_accuracy: 0.6134 - val_loss: 2.7209

# %%
# to save the model for deployment
# h5 -> h5 models represent HDF5 format
# It stores model's optimizers state, model architecture, training configuration, weights
model.save('emotion_detection_model.h5')
print("Model Saved")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model Saved
